# %% [markdown]
# # 기계 학습과 관련한 파이썬 패키지에 탑재된 예제 자료 사용하기

# %% [markdown]
# ## sklearn 패키지
#
# sklearn.datasets 모듈에 정의된 다음 함수로 예제 데이터를 얻을 수 있다.
# 자세한 사항은 [문서](https://scikit-learn.org/stable/datasets/index.html)를 참조하기 바란다.
#
# 1. load_boston()
# 2. load_iris()
# 3. load_diabetes()
# 4. load_digits()
# 5. load_linnerud()
# 6. load_wine()
# 7. load_breast_cancer()
# 8. fetch_olivetti_faces()
# 9. fetch_20newsgroups()
# 10. fetch_20newsgroups_vectorized()
# 11. fetch_lfw_people()
# 12. fetch_lfw_pairs()
# 13. fetch_covtype()
# 14. fetch_rcv1()
# 15. fetch_kddcup99()
# 16. fetch_california_housing()

# %%
from sklearn.datasets import load_iris
iris = load_iris()

print(type(iris))
# Out:
# <class 'sklearn.utils.Bunch'>

# %%
X = iris.data
y = iris.target

# %%
import pandas as pd
X = pd.DataFrame(X, columns=iris.feature_names)
y = pd.DataFrame(y)

# %%
X.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %% [markdown]
# ## seaborn 패키지
#
# seaborn에 정의된 `get_dataset_names()` 함수와 `load_dataset()` 함수로 예제 데이터를 얻을 수 있다.
# 자세한 사항은 [문서](https://seaborn.pydata.org/generated/seaborn.load_dataset.html)를 참조하기 바란다.

# %%
import seaborn as sns
sns.get_dataset_names()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/utils.py:373: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 373 of the file /usr/local/lib/python3.6/dist-packages/seaborn/utils.py. To get rid of this warning, pass the additional argument 'features="html.parser"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)
# ['anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'iris',
#  'mpg',
#  'planets',
#  'tips',
#  'titanic']

# %%
titanic = sns.load_dataset('titanic')

# %%
type(titanic)
# Out:
# pandas.core.frame.DataFrame

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
# survived       891 non-null int64
# pclass         891 non-null int64
# sex            891 non-null object
# age            714 non-null float64
# sibsp          891 non-null int64
# parch          891 non-null int64
# fare           891 non-null float64
# embarked       889 non-null object
# class          891 non-null category
# who            891 non-null object
# adult_male     891 non-null bool
# deck           203 non-null category
# embark_town    889 non-null object
# alive          891 non-null object
# alone          891 non-null bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.6+ KB
